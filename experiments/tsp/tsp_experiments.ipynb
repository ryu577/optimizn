# Best cost updated to:155.50801807158774
# Best cost updated to:154.18917158237787
# Best cost updated to:153.8648295842738
# Best cost updated to:153.75672837305126
# Best cost updated to:152.3371483318569
# Best cost updated to:151.26218840227025
# Best cost updated to:150.98313391605706
# Best cost updated to:150.70343046328784
# Best cost updated to:150.5471981553898
# Best cost updated to:149.66915594239697
# Best cost updated to:146.5488105317482
# Best cost updated to:146.3659781470087
# Best cost updated to:145.68806796201577
# Best cost updated to:145.445442665325
# Best cost updated to:145.07633337504097
# Best cost updated to:144.71760708804172
# Best cost updated to:144.05966810274032
# Best cost updated to:140.70816267141012
# Best cost updated to:139.20067320082973
# Best cost updated to:138.9690370275471
# Best cost updated to:137.5664149822464
# Best cost updated to:136.84712313022655
# Best cost updated to:136.6831306867574
# Best cost updated to:136.19731025795892
# Best cost updated to:134.72041723951602
# Best cost updated to:134.71223065590954
# Best cost updated to:134.43784602104327
# Best cost updated to:134.23620496707773
# Best cost updated to:133.83905252050582
# Best cost updated to:133.68279691616357
# Best cost updated to:133.59745135180717
# Best cost updated to:133.19263070667182
# Best cost updated to:133.0029194558069
# Best cost updated to:132.82008707106743
# Iteration: 10000 Current best solution: 132.82008707106743
# Best cost updated to:132.46136078406818
# Best cost updated to:132.12434631568726
# Best cost updated to:131.08412994674688
# Iteration: 20000 Current best solution: 131.08412994674688
# Iteration: 30000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 414.30500833230553
# Switching to a completely random solution.
# with cost: 423.0929461693824
# Switching to a completely random solution.
# with cost: 447.482697127598
# Switching to a completely random solution.
# with cost: 411.00478825206915
# Iteration: 40000 Current best solution: 131.08412994674688
# Iteration: 50000 Current best solution: 131.08412994674688
# Iteration: 60000 Current best solution: 131.08412994674688
# c:\Users\asathiya\anaconda3\envs\optimizn\lib\site-packages\optimizn-0.0.3-py3.9.egg\optimizn\combinatorial\anneal.py:57: RuntimeWarning: overflow encountered in exp
#   eps = np.exp(cost_del / temprature)
# Iteration: 70000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 409.6876587941763
# Switching to a completely random solution.
# with cost: 410.7653876053512
# Iteration: 80000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 436.63207782629206
# Iteration: 90000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 429.16417089863467
# Iteration: 100000 Current best solution: 131.08412994674688
# Iteration: 110000 Current best solution: 131.08412994674688
# Iteration: 120000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 404.47967437319096
# Iteration: 130000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 403.55025569239234
# Iteration: 140000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 436.4097978477493
# Switching to a completely random solution.
# with cost: 424.1571564234264
# Iteration: 150000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 408.99202850960273
# Switching to a completely random solution.
# with cost: 453.97820693816817
# Switching to a completely random solution.
# with cost: 424.4983172576993
# Iteration: 160000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 396.17718210609223
# Switching to a completely random solution.
# with cost: 415.05430479264726
# Iteration: 170000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 436.21652132192617
# Iteration: 180000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 409.70585973077993
# Switching to a completely random solution.
# with cost: 415.40596585914767
# Iteration: 190000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 417.4239765096255
# Iteration: 200000 Current best solution: 131.08412994674688
# Iteration: 210000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 424.20531327761404
# Iteration: 220000 Current best solution: 131.08412994674688
# Iteration: 230000 Current best solution: 131.08412994674688
# Iteration: 240000 Current best solution: 131.08412994674688
# Iteration: 250000 Current best solution: 131.08412994674688
# Iteration: 260000 Current best solution: 131.08412994674688
# Iteration: 270000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 467.7331028799513
# Iteration: 280000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 440.82358795935846
# Switching to a completely random solution.
# with cost: 417.8034669321729
# Iteration: 290000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 433.01247433350943
# Iteration: 300000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 450.00651503700806
# Switching to a completely random solution.
# with cost: 391.0536225133795
# Iteration: 310000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 398.5589391778889
# Switching to a completely random solution.
# with cost: 408.69093225105667
# Iteration: 320000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 445.58037595660574
# Iteration: 330000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 426.4223317280498
# Switching to a completely random solution.
# with cost: 378.4605961976206
# Iteration: 340000 Current best solution: 131.08412994674688
# Iteration: 350000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 446.7572121028967
# Switching to a completely random solution.
# with cost: 427.8640506482269
# Switching to a completely random solution.
# with cost: 448.15207592362304
# Iteration: 360000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 382.4534019078845
# Iteration: 370000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 436.58132486144416
# Switching to a completely random solution.
# with cost: 416.7474045655852
# Switching to a completely random solution.
# with cost: 383.08746207894455
# Iteration: 380000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 436.41233267345984
# Switching to a completely random solution.
# with cost: 428.7181222021003
# Switching to a completely random solution.
# with cost: 448.3913319837957
# Switching to a completely random solution.
# with cost: 421.6100406467956
# Iteration: 390000 Current best solution: 131.08412994674688
# Iteration: 400000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 433.282807724332
# Iteration: 410000 Current best solution: 131.08412994674688
# Iteration: 420000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 455.6598480035239
# Iteration: 430000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 393.9562902727339
# Iteration: 440000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 421.1705356681012
# Iteration: 450000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 460.8664696710701
# Switching to a completely random solution.
# with cost: 388.2427588648434
# Iteration: 460000 Current best solution: 131.08412994674688
# Iteration: 470000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 458.31781056037124
# Switching to a completely random solution.
# with cost: 419.6519590799571
# Iteration: 480000 Current best solution: 131.08412994674688
# Iteration: 490000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 395.779877164804
# Switching to a completely random solution.
# with cost: 455.2970217896573
# Iteration: 500000 Current best solution: 131.08412994674688
# Iteration: 510000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 435.2104106916972
# Iteration: 520000 Current best solution: 131.08412994674688
# Iteration: 530000 Current best solution: 131.08412994674688
# Switching to a completely random solution.
# with cost: 443.2526025514564
# Switching to a completely random solution.
# with cost: 447.7013624280558
# Switching to a completely random solution.
# with cost: 387.7026831278641
# Iteration: 540000 Current best solution: 131.08412994674688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 exp1_results = run_tsp_experiments(50, 1, 3)
#       2 exp2_results = run_tsp_experiments(100, 2, 3)
#       3 exp3_results = run_tsp_experiments(200, 4, 3)
#
# File c:\Users\asathiya\anaconda3\envs\optimizn\lib\site-packages\optimizn-0.0.3-py3.9.egg\experiments\tsp_experiments.py:29, in run_tsp_experiments(num_cities, compute_time_mins, num_trials)
#      27 tsp_sa = TravSalsmn(city_graph)
#      28 s = time.time()
# ---> 29 tsp_sa.anneal(n_iter=MAX_ITERS, time_limit=compute_time_mins * 60)
#      30 e = time.time()
#      31 tsp_sa.persist()
#
# File c:\Users\asathiya\anaconda3\envs\optimizn\lib\site-packages\optimizn-0.0.3-py3.9.egg\optimizn\combinatorial\anneal.py:54, in SimAnnealProblem.anneal(self, n_iter, reset_p, time_limit)
#      52     reset = True
#      53 else:
# ---> 54     self.new_candidate = self.next_candidate(self.candidate)
#      55     self.new_cost = self.cost(self.new_candidate)
#      56 cost_del = self.cost_delta(self.new_cost, self.current_cost)
#
# File c:\Users\asathiya\anaconda3\envs\optimizn\lib\site-packages\optimizn-0.0.3-py3.9.egg\optimizn\combinatorial\tst_anneal\trav_salsmn.py:59, in TravSalsmn.next_candidate(self, candidate)
#      57 def next_candidate(self, candidate):
#      58 	nu_candidate = deepcopy(candidate)
# ---> 59 	swaps = np.random.choice(
#      60 		np.arange(len(candidate)), size=2, replace=False)
#      61 	to_swap = nu_candidate[swaps]
#      62 	nu_candidate[swaps[0]] = to_swap[1]
#
# KeyboardInterrupt:

# %%
exp1_results
# Out:
# {'sa1': [128.4755372819393, 128.4755372819393],
#  'sa1_time': [60.00079655647278, 60.00004744529724],
#  'bnb': [132.94476473328686, 131.9128210352266],
#  'bnb_time': [60.01314663887024, 60.02255296707153],
#  'sa2': [114.77231710703163, 113.11751530551231],
#  'sa2_time': [5.7240211963653564, 7.792557954788208]}

# %%
# exp2_results

# %%
# exp3_results
